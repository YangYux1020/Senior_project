# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import csv
import preprocessing as pre

# %%
year_groups = {
    "Group1",
    "Group2",
    "Group3",
    "Group4",
    "Group5"
}

X_train_scaled, X_test_scaled, base_scaler = pre.load_and_preprocess(f'./data_set/balance_data_Group1.csv', 
                                                                                scaler=None, 
                                                                                fit=True)
X_train_df = pd.DataFrame(X_train_scaled, columns=['DIQ010'])
X_test_df = pd.DataFrame(X_test_scaled, columns=['DIQ010'])
        
X_train_scaled.to_parquet(f"../data/processed/train/partition_Group1_train.parquet")
X_test_scaled.to_parquet(f"../data/processed/test/partition_Group1_test.parquet")
     

for group_name in year_groups:
    if group_name == "Group1":
        continue
                     
    else:
        X_train_scaled, X_test_scaled, _ = pre.load_and_preprocess(f'./data_set/balance_data_{group_name}.csv', 
                                                                scaler=base_scaler, 
                                                                fit=False)
        X_train_df = pd.DataFrame(X_train_scaled, columns=['DIQ010'])
        X_test_df = pd.DataFrame(X_test_scaled, columns=['DIQ010'])
                
        X_train_scaled.to_parquet(f"../data/processed/train/partition_{group_name}_train.parquet")
        X_test_scaled.to_parquet(f"../data/processed/test/partition_{group_name}_test.parquet")
