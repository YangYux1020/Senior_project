# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import csv
from preprocessing import load_and_preprocess

# %%
year_groups = {
    "Group1",
    "Group2",
    "Group3",
    "Group4",
    "Group5"
}

for group_name in year_groups:
    if group_name == "Group1":
        X_client, Y_client, global_scaler = load_and_preprocess(f'./data_set/balance_data_{group_name}.csv', fit=True)
        
    
    load_and_preprocess(f'./data_set/balance_data_{group_name}.csv', scaler=global_scaler, fit=False)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[3], line 12
#       9 for group_name in year_groups:
#      10     df = pd.read_csv(f'./data_set/balance_data_{group_name}.csv')
# ---> 12     load_and_preprocess(f'./data_set/balance_data_{group_name}.csv')
#
# File e:\專題\Senior_project\Schedule\260920\src\preprocessing.py:54, in load_and_preprocess(path, scaler, imputer, fit)
#      52     X_scaled = scaler.fit_transform(X_imputed) # 僅在基準分區（或集中式訓練集）上計算均值與標準差
#      53 else:
# ---> 54     X_scaled = scaler.transform(X_imputed) # 其他分區嚴格套用基準分區的縮放標準，避免資料外洩與尺度不一
#      56 return X_scaled, Y, scaler
#
# File c:\Users\Yang\.conda\envs\senior_project\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# ...
